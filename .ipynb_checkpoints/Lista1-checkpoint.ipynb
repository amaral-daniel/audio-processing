# %%
import matplotlib.pyplot as plt
from scipy import signal
from scipy.io import wavfile
import os
import IPython
import math

# %%
base_dir="/Users/danielmendonca/git/AudioProcessing/AudioFiles"
file_1="Brandenburg Concerto No. 3 In G Major- I-Allegro_RED.wav"
file_2="Two Part Invention In F Major_RED.wav"
file_3="When I am laid in earth (Dido_s lament)_RED.wav"
file_4="há gente aqui_RED.wav"

# %% [markdown]
# #### Brandenburg Concerto No. 3 In G Major- I-Allegro

# %%
file_path = os.path.join(base_dir,file_1)
sample_rate,samples = wavfile.read(file_path)
IPython.display.Audio(file_path)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Since the variation sounds fast, we set the window length to 20ms, which is the minimum variation we (humans) can hear

# %%
window_length=0.02 #20ms, minimum variation we (humans) can hear
nfft=int(window_length*sample_rate)
nfft
# Out:
# 882

# %%
plt.specgram(samples, Fs=sample_rate,cmap='jet_r',NFFT=nfft,noverlap=nfft/2, title= 'Spectrogram',x_label='time (s)', y_label='frequency (Hz)')
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-0c5c6daa7e3a> in <module>()
# ----> 1 plt.specgram(samples, Fs=sample_rate,cmap='jet_r',NFFT=nfft,noverlap=nfft/2, title= 'Spectrogram',x_label='time (s)', y_label='frequency (Hz)')
#       2 plt.colorbar()
#       3 plt.show()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in specgram(x, NFFT, Fs, Fc, detrend, window, noverlap, cmap, xextent, pad_to, sides, scale_by_freq, mode, scale, vmin, vmax, hold, data, **kwargs)
#    3425                           xextent=xextent, pad_to=pad_to, sides=sides,
#    3426                           scale_by_freq=scale_by_freq, mode=mode, scale=scale,
# -> 3427                           vmin=vmin, vmax=vmax, data=data, **kwargs)
#    3428     finally:
#    3429         ax._hold = washold
#
# ...

# %% [markdown]
# #### Two Part Invention In F Major

# %%
file_path = os.path.join(base_dir,file_2)
sample_rate,samples = wavfile.read(file_path)
IPython.display.Audio(os.path.join(file_path))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
window_length=0.02 #20ms, minimum variation we (humans) can hear
nfft=int(window_length*sample_rate)

# %%
plt.specgram(samples, Fs=sample_rate,cmap='jet_r',NFFT=nfft,noverlap=nfft/2)
plt.colorbar()
plt.show()
# Out:
# /Users/danielmendonca/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:7221: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)

# %% [markdown]
# #### When I am laid in earth (Dido_s lament)

# %%
file_path = os.path.join(base_dir,file_3)
sample_rate,samples = wavfile.read(file_path)
IPython.display.Audio(os.path.join(file_path))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
window_length=0.02
nfft=int(window_length*sample_rate)

# %%
plt.specgram(samples, Fs=sample_rate,cmap='jet_r',NFFT=nfft,noverlap=nfft/2)
plt.colorbar()
plt.show()
# Out:
# /Users/danielmendonca/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:7221: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)

# %% [markdown]
# #### há gente aqui

# %%
file_path = os.path.join(base_dir,file_4)
sample_rate,samples = wavfile.read(file_path)
IPython.display.Audio(os.path.join(file_path))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
window_length=0.02 #20ms, minimum variation we (humans) can hear
nfft=int(window_length*sample_rate)

# %%
plt.specgram(samples, Fs=sample_rate,cmap='jet_r',NFFT=nfft,noverlap=nfft/2)
plt.colorbar()
plt.show()
# Out:
# /Users/danielmendonca/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:7221: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)
